# %% [markdown]
# <a href="https://colab.research.google.com/github/aarushikumar/PWSkills_Assignments/blob/main/Bokeh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bokeh

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')
p = figure(title='test flower')
p.xaxis.axis_label="petal_length"
p.yaxis.axis_label="petal_width"
p.scatter(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="a64876f8-bc1f-4d35-a0d6-399d5f373299" data-root-id="p1237" style="display: contents;"></div>

# %%
output_file('test.html')
p = figure(title='test flower')
p.xaxis.axis_label="petal_length"
p.yaxis.axis_label="petal_width"
p.line(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="e36680c8-e107-4ad2-8d8c-0574d96e1aec" data-root-id="p1145" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file('line.html')
p = figure(title = 'line graph')
p.line(x,y)
show(p)
# Out:
#   <div id="e7ca0d88-0cb6-417e-88ab-28b1361eebfd" data-root-id="p1283" style="display: contents;"></div>

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file('line.html')
p = figure(title = 'line graph')
p.scatter(x,y, size=10, fill_color='red', legend_label = 'This is a Bokeh Plot ')
show(p)
# Out:
#   <div id="c57c7d1a-7f17-49df-a7ad-929239e40f8d" data-root-id="p1494" style="display: contents;"></div>
